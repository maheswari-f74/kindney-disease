# %% [markdown]
# <a href="https://colab.research.google.com/github/maheswari-f74/kindney-disease/blob/main/kidney_chronic_disease_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras

# %%
from keras.layers import Dense

# %%
from keras.models import Sequential
model = Sequential()   #Model Creation

# %%
import pandas as pd

dt = pd.read_csv('/content/kidney disease.csv')   #Data Loading
dt.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
dt = dt.dropna()

# %%
for i in dt.columns:
  if dt[i].dtype == 'object':
    dt[i] = dt[i].astype('category').cat.codes

# %%
dt.corr()
# Out:
#                       id       age        bp        sg        al        su  \
# id              1.000000 -0.236508 -0.282317  0.676958 -0.745822 -0.331072
# age            -0.236508  1.000000  0.079712 -0.277303  0.253380  0.207711
# bp             -0.282317  0.079712  1.000000 -0.198897  0.322507  0.243828
# sg              0.676958 -0.277303 -0.198897  1.000000 -0.712331 -0.448477
# al             -0.745822  0.253380  0.322507 -0.712331  1.000000  0.521448
# su             -0.331072  0.207711  0.243828 -0.448477  0.521448  1.000000
# rbc             0.492647 -0.147971 -0.316670  0.500494 -0.489941 -0.256568
# pc              0.690055 -0.188907 -0.179834  0.630323 -0.752956 -0.335901
# pcc            -0.442907  0.124032  0.206507 -0.460050  0.503341  0.177327
# ba             -0.333936  0.068353  0.174555 -0.516392  0.516104  0.381929
# bgr            -0.449157  0.301915  0.190113 -0.544781  0.518123  0.730050
# ...

# %%
dt = dt.drop(['su','ba','wc','rc','cad'],axis=1)

# %%
dt.tail(1)
# Out:
#       id   age    bp     sg   al  rbc  pc  pcc    bgr    bu  ...    sod  pot  \
# 399  399  58.0  80.0  1.025  0.0    1   1    0  131.0  18.0  ...  141.0  3.5
#
#      hemo  pcv  htn  dm  appet  pe  ane  classification
# 399  15.8   31    0   0      0   0    0               1
#
# [1 rows x 21 columns]

# %%
x = dt.iloc[:,0:-1]   #Feature Selection
y = dt['classification']

# %%
x
# Out:
#       id   age    bp     sg   al  rbc  pc  pcc    bgr     bu   sc    sod  pot  \
# 3      3  48.0  70.0  1.005  4.0    1   0    1  117.0   56.0  3.8  111.0  2.5
# 9      9  53.0  90.0  1.020  2.0    0   0    1   70.0  107.0  7.2  114.0  3.7
# 11    11  63.0  70.0  1.010  3.0    0   0    1  380.0   60.0  2.7  131.0  4.2
# 14    14  68.0  80.0  1.010  3.0    1   0    1  157.0   90.0  4.1  130.0  6.4
# 20    20  61.0  80.0  1.015  2.0    0   0    0  173.0  148.0  3.9  135.0  5.2
# ..   ...   ...   ...    ...  ...  ...  ..  ...    ...    ...  ...    ...  ...
# 395  395  55.0  80.0  1.020  0.0    1   1    0  140.0   49.0  0.5  150.0  4.9
# 396  396  42.0  70.0  1.025  0.0    1   1    0   75.0   31.0  1.2  141.0  3.5
# 397  397  12.0  80.0  1.020  0.0    1   1    0  100.0   26.0  0.6  137.0  4.4
# 398  398  17.0  60.0  1.025  0.0    1   1    0  114.0   50.0  1.0  135.0  4.9
# 399  399  58.0  80.0  1.025  0.0    1   1    0  131.0   18.0  1.1  141.0  3.5
#
# ...

# %%
from sklearn.model_selection import train_test_split   #Data Split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25)

# %%
print(x.shape,y.shape,x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (158, 20) (158,) (118, 20) (40, 20) (118,) (40,)

# %%
model.add(Dense(units=20,activation='relu', input_shape=(x_train.shape[1],)))  #Model Architecture
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.add(Dense(units=10,activation='relu'))

# %%
model.add(Dense(units=1,activation='sigmoid'))

# %%
model.build(input_shape=(None,20))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           210 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 641 (2.50 KB)
#  Trainable params: 641 (2.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=50,batch_size=10,steps_per_epoch=x_train.shape[0]//10)
# Out:
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9914 - loss: 0.0205
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0038
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9977 - loss: 0.0113
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0438
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0040
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8750 - loss: 0.3036
# Epoch 7/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0033
# Epoch 8/50
# ...

# %%
y_pred = model.predict(x_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step

# %%
y_pred = (y_pred > 0.5).astype(int)

# %%
from sklearn.metrics import accuracy_score  #Evaluation
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
model.save('kidney.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
x_train
# Out:
#       id   age    bp     sg   al  rbc  pc  pcc    bgr    bu   sc    sod  pot  \
# 318  318  61.0  70.0  1.025  0.0    1   1    0  120.0  29.0  0.7  137.0  3.5
# 157  157  62.0  70.0  1.025  3.0    1   0    0  122.0  42.0  1.7  136.0  4.7
# 279  279  24.0  70.0  1.025  0.0    1   1    0  140.0  23.0  0.6  140.0  4.7
# 351  351  29.0  80.0  1.020  0.0    1   1    0   83.0  49.0  0.9  139.0  3.3
# 375  375  70.0  80.0  1.020  0.0    1   1    0   74.0  41.0  0.5  143.0  4.5
# ..   ...   ...   ...    ...  ...  ...  ..  ...    ...   ...  ...    ...  ...
# 27    27  69.0  70.0  1.010  3.0    1   0    0  264.0  87.0  2.7  130.0  4.0
# 159  159  59.0  80.0  1.010  1.0    0   1    0  303.0  35.0  1.3  122.0  3.5
# 242  242  69.0  70.0  1.010  4.0    1   0    1  214.0  96.0  6.3  120.0  3.9
# 171  171  83.0  70.0  1.020  3.0    1   1    0  102.0  60.0  2.6  115.0  5.7
# 368  368  30.0  80.0  1.025  0.0    1   1    0   82.0  42.0  0.7  146.0  5.0
#
#      hemo  pcv  htn  dm  appet  pe  ane
# ...

# %%
x_train.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'rbc', 'pc', 'pcc', 'bgr', 'bu', 'sc',
#        'sod', 'pot', 'hemo', 'pcv', 'htn', 'dm', 'appet', 'pe', 'ane'],
#       dtype='object')
